# %%
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
import microhapdb
import numpy
import pandas
import seaborn

# %% [markdown]
# ## Data prep

# %%
m = microhapdb.markers
f = microhapdb.frequencies
pops = sorted(microhapdb.populations[microhapdb.populations.Source == '1KGP'].ID)
x = range(len(pops))

# %% [markdown]
# ## Grabbing representative markers

# %%
m[(m.In > 0.3) & (m.In < 0.4) & (m.Source != '10.1016/j.fsigen.2018.05.001')].sort_values('AvgAe')
# Out:
#             Name          PermID Reference  Chrom  \
# 293   mh14KK-101  MHDBM-132db0af    GRCh38  chr14
# 47    mh02KK-003  MHDBM-13b749ff    GRCh38   chr2
# 297   mh15KK-058  MHDBM-d6c594d2    GRCh38  chr15
# 326   mh16KK-062  MHDBM-69423f7f    GRCh38  chr16
# 119   mh05KK-121  MHDBM-5f4e13a2    GRCh38   chr5
# 179   mh09KK-020  MHDBM-13b503c9    GRCh38   chr9
# 33   mh02USC-2pA  MHDBM-1734fe04    GRCh38   chr2
# 18   mh01USC-1pD  MHDBM-8098d345    GRCh38   chr1
# 166   mh08KK-039  MHDBM-5078e94d    GRCh38   chr8
# 393   mh21KK-324  MHDBM-eb207470    GRCh38  chr21
# 108   mh05KK-170  MHDBM-22ddbb7d    GRCh38   chr5
# 81   mh03USC-3qC  MHDBM-eacabfd9    GRCh38   chr3
#
#                                                Offsets   AvgAe      In  \
# 293                                105543139,105543234  1.7532  0.3666
# 47                       108969856,108969914,108969980  2.1057  0.3022
# 297                         28120284,28120471,28120586  2.2110  0.3799
# 326                         87468088,87468129,87468385  2.3563  0.3633
# 119                33951720,33951955,33951986,33952000  2.5124  0.3663
# 179                16795160,16795164,16795242,16795287  2.6851  0.3285
# 33                 10810991,10811035,10811042,10811069  2.7695  0.3702
# 18                       106227453,106227475,106227487  3.1574  0.3706
# 166    3659269,3659313,3659351,3659400,3659461,3659481  4.1595  0.3955
# 393                45294633,45294725,45294776,45294791  4.5506  0.3071
# 108                    2447909,2447937,2448031,2448045  5.8163  0.3436
# 81   196653025,196653034,196653044,196653084,196653121  6.0269  0.3280
#
#                            Source
# 293                        ALFRED
# 47                         ALFRED
# 297                        ALFRED
# 326                        ALFRED
# 119                        ALFRED
# 179                        ALFRED
# 33   10.1016/j.fsigen.2019.102213
# 18   10.1016/j.fsigen.2019.102213
# 166                        ALFRED
# 393                        ALFRED
# 108                        ALFRED
# 81   10.1016/j.fsigen.2019.102213

# %%
m[(m.AvgAe > 4.0) & (m.AvgAe < 4.5) & (m.Source != '10.1016/j.fsigen.2018.05.001')].sort_values('In')
# Out:
#              Name          PermID Reference  Chrom  \
# 9      mh01KK-205  MHDBM-1f7eaca2    GRCh38   chr1
# 117    mh05CP-010  MHDBM-df4e5f79    GRCh38   chr5
# 247    mh12CP-008  MHDBM-003a7083    GRCh38  chr12
# 279    mh13KK-223  MHDBM-4088f2e4    GRCh38  chr13
# 60      mh02AT-07  MHDBM-eb83984f    GRCh38   chr2
# 59     mh02KK-136  MHDBM-eb83984f    GRCh38   chr2
# 385    mh21KK-315  MHDBM-e965ffea    GRCh38  chr21
# 369  mh19USC-19qB  MHDBM-7b40359b    GRCh38  chr19
# 265    mh13KK-213  MHDBM-d5615acf    GRCh38  chr13
# 281  mh13USC-13qD  MHDBM-780fecae    GRCh38  chr13
# 311    mh16KK-049  MHDBM-9da28473    GRCh38  chr16
# 269  mh13USC-13qA  MHDBM-31aaadda    GRCh38  chr13
# 270    mh13KK-217  MHDBM-58fe77e7    GRCh38  chr13
# 95     mh04KK-013  MHDBM-33a849c2    GRCh38   chr4
# 153   mh07USC-7pB  MHDBM-fb03f07f    GRCh38   chr7
# 116   mh05USC-5pA  MHDBM-c29d8dc9    GRCh38   chr5
# 25     mh01KK-117  MHDBM-39dc025f    GRCh38   chr1
# 364    mh19KK-299  MHDBM-8cbeb11c    GRCh38  chr19
# 84     mh04KK-030  MHDBM-1e252b7e    GRCh38   chr4
# 357    mh18KK-293  MHDBM-13ed6da8    GRCh38  chr18
# 358     mh18AT-39  MHDBM-13ed6da8    GRCh38  chr18
# 217    mh11KK-180  MHDBM-6d611fb7    GRCh38  chr11
# 256  mh12USC-12qB  MHDBM-b12bc2a2    GRCh38  chr12
# 405  mh22USC-22qB  MHDBM-84c38e1d    GRCh38  chr22
# 176   mh09USC-9pA  MHDBM-3eb8b948    GRCh38   chr9
# 166    mh08KK-039  MHDBM-5078e94d    GRCh38   chr8
#
#                                              Offsets   AvgAe      In  \
# 9                18396197,18396218,18396306,18396351  4.0654  0.0717
# 117              17903164,17903183,17903208,17903213  4.4028  0.0803
# 247                          1996655,1996658,1996688  4.1092  0.0918
# 279          110154351,110154394,110154411,110154504  4.0458  0.1173
# 60                     227227672,227227689,227227742  4.0513  0.1190
# 59                     227227672,227227689,227227742  4.0513  0.1190
# 385                       20507773,20507878,20507918  4.3647  0.1292
# 369                       53714387,53714389,53714413  4.0756  0.1368
# 265                       23191401,23191495,23191541  4.0188  0.1518
# 281          111435605,111435617,111435623,111435672  4.2401  0.1535
# 311          7159206,7159245,7159265,7159309,7159379  4.4743  0.1576
# 269              32979441,32979488,32979489,32979510  4.4067  0.1615
# 270              46291794,46291834,46291948,46291986  4.4789  0.1662
# 95      67578383,67578461,67578473,67578538,67578583  4.1089  0.1700
# 153              25407969,25407971,25407994,25408020  4.3649  0.1746
# 116              11046016,11046056,11046060,11046080  4.1459  0.1754
# 25           204664211,204664268,204664371,204664397  4.4565  0.1933
# 364     22546697,22546748,22546779,22546810,22546850  4.1592  0.2335
# 84                   3664642,3664675,3664743,3664756  4.2975  0.2406
# 357              78329885,78329906,78329944,78329967  4.0036  0.2495
# 358              78329885,78329906,78329944,78329967  4.0036  0.2495
# 217                  1669560,1669680,1669738,1669753  4.0916  0.2604
# 256              68114495,68114515,68114543,68114572  4.0409  0.2835
# 405     48665163,48665174,48665181,48665203,48665215  4.3459  0.2916
# 176          2288646,2288676,2288699,2288709,2288717  4.4514  0.2989
# 166  3659269,3659313,3659351,3659400,3659461,3659481  4.1595  0.3955
#
#                            Source
# 9                          ALFRED
# 117                        ALFRED
# 247                        ALFRED
# 279                        ALFRED
# 60                  ISFG2019:P597
# 59                         ALFRED
# 385                        ALFRED
# 369  10.1016/j.fsigen.2019.102213
# 265                        ALFRED
# 281  10.1016/j.fsigen.2019.102213
# 311                        ALFRED
# 269  10.1016/j.fsigen.2019.102213
# 270                        ALFRED
# 95                         ALFRED
# 153  10.1016/j.fsigen.2019.102213
# 116  10.1016/j.fsigen.2019.102213
# 25                         ALFRED
# 364                        ALFRED
# 84                         ALFRED
# 357                        ALFRED
# 358                 ISFG2019:P597
# 217                        ALFRED
# 256  10.1016/j.fsigen.2019.102213
# 405  10.1016/j.fsigen.2019.102213
# 176  10.1016/j.fsigen.2019.102213
# 166                        ALFRED

# %% [markdown]
# ## Plotting allele frequency distributions

# %%
def plot_af(marker, axis, ylabel=False):
    mdata = m[m.Name == marker].iloc[0]
    alleles = f[(f.Marker == marker) & (f.Population.isin(pops)) & (f.Frequency > 0.0)].Allele.unique()
    colors = seaborn.color_palette('hls', len(alleles))
    base_bars = [0.0] * len(pops)
    for allele, color in zip(alleles, colors):
        bars = list()
        for population in pops:
            result = f[(f.Marker == marker) & (f.Population == population) & (f.Allele == allele)]
            freq = 0.0
            if len(result) > 0:
                assert len(result) == 1
                freq = result.Frequency.iloc[0]
            bars.append(freq)
        plt.bar(x, bars, 0.8, bottom=base_bars, color=color)
        base_bars = [a + b for a, b in zip(base_bars, bars)]
    _ = axis.grid(linestyle=':', color='#999999')
    _ = axis.set_xticks(x)
    _ = axis.set_xticklabels(pops, rotation=90)
    _ = axis.set_xlabel('Population')
    if ylabel:
        _ = axis.set_ylabel(ylabel)
    _ = axis.set_title(f'{marker} (N={len(alleles)}; $A_e$={mdata.AvgAe:.2f}; $I_n$={mdata.In:.3f})')

# %%
matplotlib.rcParams['axes.labelsize'] = 16
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 12), dpi=150, sharex='col', sharey='row')
fig.patch.set_facecolor('white')

markers_to_plot = [
    'mh14KK-101', 'mh08KK-039', 'mh03USC-3qC',
    'mh05CP-010', 'mh05USC-5pA', 'mh08KK-039',
]
for i, marker in enumerate(markers_to_plot):
    axis = plt.subplot(2, 3, i + 1)
    ylabel = 'Allele Frequency' if i in (0, 3) else False
    plot_af(marker, axis, ylabel=ylabel)

plt.subplots_adjust(hspace=0.35, wspace=0.1)
fig.savefig('microhaps-af-dist.pdf')

# %% [markdown]
# ## Appendix: sandbox

# %%
marker = 'mh13KK-218'
mdata = m[m.Name == marker].iloc[0]
alleles = f[(f.Marker == marker) & (f.Population.isin(pops)) & (f.Frequency > 0.0)].Allele.unique()
x = range(len(pops))
base_bars = [0.0] * len(pops)
for allele in alleles:
    bars = list()
    for population in pops:
        result = f[(f.Marker == marker) & (f.Population == population) & (f.Allele == allele)]
        freq = 0.0
        if len(result) > 0:
            assert len(result) == 1
            freq = result.Frequency.iloc[0]
        bars.append(freq)
    plt.bar(x, bars, 0.8, bottom=base_bars)
    base_bars = [a + b for a, b in zip(base_bars, bars)]
_ = plt.grid(linestyle=':', color='#999999')
_ = plt.xticks(x, pops, rotation=90)
_ = plt.xlabel('Population')
_ = plt.ylabel('Allele Frequency')
_ = plt.title(f'mh13KK-218 (N={len(alleles)}; $A_e$={mdata.AvgAe:.2f}; $I_n$={mdata.In:.3f})')

# %%
marker = 'mh17KK-105'
mdata = m[m.Name == marker].iloc[0]
alleles = f[(f.Marker == marker) & (f.Population.isin(pops)) & (f.Frequency > 0.0)].Allele.unique()
x = range(len(pops))
base_bars = [0.0] * len(pops)
for allele in alleles:
    bars = list()
    for population in pops:
        result = f[(f.Marker == marker) & (f.Population == population) & (f.Allele == allele)]
        freq = 0.0
        if len(result) > 0:
            assert len(result) == 1
            freq = result.Frequency.iloc[0]
        bars.append(freq)
    plt.bar(x, bars, 0.8, bottom=base_bars)
    base_bars = [a + b for a, b in zip(base_bars, bars)]
_ = plt.grid(linestyle=':', color='#999999')
_ = plt.xticks(x, pops, rotation=90)
_ = plt.xlabel('Population')
_ = plt.ylabel('Allele Frequency')
_ = plt.title(f'{marker} (N={len(alleles)}; $A_e$={mdata.AvgAe:.2f}; $I_n$={mdata.In:.3f})')
